# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukec-lehighu/CSE337-Labs/blob/main/lab5_approximation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 5: Value-Function Approximation
#
#
# ## Exercise 1 SGD
# Many real-world processes can be modeled as nonlinear relationships, and SGD is a standard tool to fit those models from data.
#
# **Example: Predicting energy consumption in a building**
# - Energy usage depends on **temperature**, **time of day**, and **occupancy**.
# - If you plot the data, the relationship might not be linear — it curves.
# - A simple way to approximate this nonlinear relation is to fit a **polynomial function** of temperature (or time).
#
# Now, imagine you’re collecting data continuously:
# - You get one data point (temperature, usage) at a time.
# - Instead of waiting to collect all data and computing a full batch update, you update your model incrementally with **SGD**.
# - This makes your learning **online, adaptive, and scalable** — just like in reinforcement learning.
#
# ---
#
# In this exercise, approximating a cubic polynomial is a simplified version of **predicting a nonlinear real-world phenomenon**.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data based on a cubic polynomial with Gaussian noise
np.random.seed(42)  # for reproducibility
n_samples = 100
x = np.linspace(-5, 5, n_samples)
# Define the true cubic polynomial function
def true_function(x):
  return 0.1 * x**3 - 0.5 * x**2 + 2 * x + 5

y_true = true_function(x)
noise = np.random.normal(0, 2, n_samples)  # Gaussian noise with mean 0 and std dev 2
y = y_true + noise

# Optional: Plot the generated data
plt.scatter(x, y, label='Generated Data')
plt.plot(x, y_true, color='red', label='True Function')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Generated Data with Cubic Polynomial and Gaussian Noise')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the given a dataset of input–output pairs `(x, y)` where the underlying relationship is approximately polynomial.
#
# a. Use a **linear model with polynomial features**: Write a function that takes an input `x` and a weight vector `w`, and return the predicted value y_hat.
#
#    - y_hat(x; w) = w0 + w1 * x + w2 * x^2 + w3 * x^3
#
#    where w0, w1, w2, w3 are the parameters to be learned.
#
# b. **Loss function (Mean Squared Error)**:
#    Write a function that computes the loss for one training point `(x, y)`:
#
#      - Formula: `loss = 0.5 * (y - y_hat)**2`
#
# c. **SGD update**:   Derive the gradient of the loss with respect to each parameter (w0, w1, w2, w3).
#    - Write a function:
#
#      ```python
#      def sgd_update(x, y, w, alpha):
#          """
#          Perform one SGD update for a single training example.
#          Input:
#              x (float) - input value
#              y (float) - true output
#              w (np.array) - current weights
#              alpha (float) - learning rate
#          Output:
#              w (np.array) - updated weights
#          """
#          # TODO: compute prediction, gradient, and update weights
#          return w
#      ```
# d. **Training loop**:
#    - Loop over the dataset.
#    - At each step, update the weights using `sgd_update`.
#    - Track the training loss after each iteration.
#
# e. **Comparison with different learning rates**
#    - Train your model using at least three different learning rates, for example:
#      - alpha = 0.001
#      - alpha = 0.01
#      - alpha = 0.1
#    - Plot training loss vs iteration for each learning rate.
#    - Plot the final fitted polynomial curves for each learning rate on the same graph with the true dataset.
#
# ---
#
# ### Deliverables
# - Code for `predict`, `mse_loss`, and `sgd_update`.
# - Training loop that runs with multiple learning rates.
# - Plot of training loss vs iteration for each learning rate.
# - Plot of the fitted polynomial vs dataset for each learning rate.
# - A short discussion:
#   - How does the learning rate affect convergence speed and stability?
#   - Which learning rate gives the best balance between speed and accuracy?

# %%
import matplotlib.pyplot as plt
import random

def predict(x, w):
  return sum([
      w[i] * x**i for i in range(len(w))
  ])

def mse_loss(x, y, w):
  return 0.5 * (y-predict(x, w))**2

def sgd_update(x, y, w, alpha):
    """
    Perform one SGD update for a single training example.
    Input:
        x (float) - input value
        y (float) - true output
        w (np.array) - current weights
        alpha (float) - learning rate
    Output:
        w (np.array) - updated weights
    """

    w = [
        w[i] + alpha*(y - predict(x, w))*(x**i) for i in range(len(w))
    ]

    return w

def train(x, y, alpha=0.01, n_params=4, epochs = 1):
  w = [0,]*n_params
  losses = []

  for e in range(epochs):
    for point in zip(x, y):
      w = sgd_update(point[0], point[1], w, alpha)

      #compute average loss over entire dataset
      losses.append(
          sum([
              mse_loss(x[i], y[i], w)/len(x) for i in range(len(x))
          ])
      )

  return w, losses

w1, loss_1 = train(x, y, alpha=0.0001, epochs=100)
w2, loss_2 = train(x, y, alpha=0.001, epochs=100)
w3, loss_3 = train(x, y, alpha=0.1, epochs=100)

x = np.linspace(-5, 5, n_samples)
line1 = [predict(xi, w1) for xi in x]
line2 = [predict(xi, w2) for xi in x]
line3 = [predict(xi, w3) for xi in x]
trueLine = [true_function(xi) for xi in x]

plt.plot(line1, label='alpha=0.001')
plt.plot(line2, label='alpha=0.01')
plt.plot(line3, label='alpha=0.1')
plt.plot(trueLine, label='true')
plt.title('Polynomials')
plt.legend(loc='lower right')
plt.show()
# Out:
# /tmp/ipython-input-2064663433.py:10: RuntimeWarning: overflow encountered in scalar power
#   return 0.5 * (y-predict(x, w))**2
# /tmp/ipython-input-2064663433.py:6: RuntimeWarning: overflow encountered in scalar multiply
#   w[i] * x**i for i in range(len(w))
# /tmp/ipython-input-2064663433.py:5: RuntimeWarning: invalid value encountered in scalar add
#   return sum([
# /tmp/ipython-input-2064663433.py:25: RuntimeWarning: invalid value encountered in scalar add
#   w[i] + alpha*(y - predict(x, w))*(x**i) for i in range(len(w))
# /tmp/ipython-input-2064663433.py:5: RuntimeWarning: overflow encountered in scalar add
#   return sum([

# %% [markdown]
# ## Exercise 2: 1000-State Random Walk with Semi-Gradient TD(0)
#
# We will study the 1,000-state Random Walk a classic reinforcement learning benchmark from Sutton & Barto.
#
# - The environment has states numbered **1 to 1000**.
# - There are two **terminal states**:
#   - State `0` on the left (reward = 0)
#   - State `1001` on the right (reward = 1)
# - Each episode starts in the **middle** at state `500`.
# - At each step, the agent moves **left or right with equal probability (0.5 each)**.
# - The episode ends when the agent reaches either terminal.
# - Discount factor: **γ = 1.0** (episodic task).
#
#
# ### Function Approximation
# Instead of storing a separate value for each state, approximate the value function with a **linear function of the state index**: V_hat(s; w0, w1) = w0 + w1 * s
#
#
#
# ---
#
# ## Instructions
# 1. **Implement the environment**:
#    - You may **use AI tools such as ChatGPT** to generate the environment code (states, transitions, rewards).
#    - Make sure you understand how the environment works.
#
# 2. **Implement the TD(0) update manually**:
#    - Do **not** use AI for this part.
#    - You must write the gradient update equations yourself using the formulas above.
#
# 3. **Train your agent**:
#    - Run several episodes (e.g., 1000 episodes).
#    - Experiment with different step sizes (`alpha`).
#
# 4. **Evaluate**:
#    - Plot the **true value function** `V*(s) = s/1001`.
#    - Plot your **learned approximation line** after training.
#    - Discuss whether the line captures the overall trend of the true values.
#
# ---
#
#
# ## Guidelines on Using AI Tools
# - You are encouraged to use AI tools (e.g., ChatGPT, Gemini, Copilot) to **generate helper code**, such as:
#   - Building the random walk environment (`reset`, `step`).
#   - Implementing the feature map φ(s).
#   - Plotting results.
# - However, **do not use AI tools to generate the TD(0) update equation**.
#   - Deriving and implementing the update is the key learning objective of this exercise.
#   - If we find code that uses an AI-generated update without understanding, the score will be zero.
#
#
# ## Deliverables
# - Python code for the environment and the TD(0) algorithm.
# - Plot the **true value function**: For state `s`, the probability of reaching the right terminal is:
#   `V*(s) = s / 1001`
# - Plot comparing the true value function and the approximated line.
# - A short discussion:
#   - How does the approximation behave for small vs large states?
#   - How does the learning rate affect convergence?
#
# ---
#
# ## Hints
# - Normalize states to `[0,1]` before using them in the line approximation to avoid very large values for w1.
# - Start with small step sizes (e.g., 0.001–0.01).
# - The approximation will not be perfect (a line cannot match the true curve), but should capture the increasing trend.

# %%
import numpy as np

# Define the environment parameters
N_STATES = 1000
START_STATE = 500
TERMINAL_LEFT_REWARD = 0
TERMINAL_RIGHT_REWARD = 1

# Represent the environment as an array (though not strictly needed for this simple environment)
# States are 1 to 1000. Terminal states are 0 and 1001.
states = np.arange(0, N_STATES + 2) # Includes terminal states 0 and 1001

def step(state, action):
  """
  Perform a step in the random walk environment.

  Args:
    state (int): The current state (1 to 1000).
    action (str): The action to take ('left' or 'right').

  Returns:
    tuple: (next_state, reward, done)
  """
  if action == 'left':
    next_state = state - 1
  elif action == 'right':
    next_state = state + 1
  else:
    raise ValueError("Invalid action. Must be 'left' or 'right'.")

  reward = 0
  done = False

  if next_state == 0:
    reward = TERMINAL_LEFT_REWARD
    done = True
  elif next_state == N_STATES + 1:
    reward = TERMINAL_RIGHT_REWARD
    done = True

  return next_state, reward, done

print("Environment set up complete.")

n_episodes = 5000

def train(alpha):
  #reset
  w = [0, 0]
  state = START_STATE

  for ep in range(n_episodes):
    while True:
      next_state, reward, done = step(state, random.choice(['left', 'right']))

      #run update
      w = [
          w[i] + alpha*(reward + predict(next_state, w)-predict(state,w)) * state**i
          for i in range(len(w))
      ]

      state = next_state

      if done:
        break
    return w

w1 = train(0.0001)
w2 = train(0.001)
w3 = train(0.01)
# Out:
# Environment set up complete.

# %%
#create plots
plt.plot([i/1001 for i in range(1001)], label='Real')
plt.plot([predict(i, w1) for i in range(1001)], label='w1')
plt.plot([predict(i, w2) for i in range(1001)], label='w2')
plt.plot([predict(i, w3) for i in range(1001)], label='w3')
plt.legend(loc='upper left')

# %% [markdown]
# # Discussion
#
# How does the approximation behave for small vs large states?
# - Since the equation being estimated is strictly linear, the approximation will always be closer to the true line in smaller states and diverge more in larger states.
#
# How does the learning rate affect convergence?
# - If the learning rate is too high, the algorithm will overshoot and not converge on the correct weight values.
# - If the learning rate is too low, the algorithm won't learn fast enough in the number of episodes per training session.

# %% [markdown]
# # Exercise 3: Solving MountainCar with Tile Coding and SARSA
#
# ## Problem Description
# In this exercise, you will solve the **MountainCar-v0** environment from Gym using **tile coding** for function approximation and the **SARSA algorithm** for learning.
#
# The **Mountain Car problem**:
# - A car is stuck in a valley and is too weak to drive straight up to the goal.
# - It must build momentum by going back and forth until it can reach the goal at `position >= 0.5`.
# - **State space**: continuous (position, velocity).
# - **Actions**: {0: push left, 1: no push, 2: push right}.
# - **Reward**: -1 per step until the goal is reached.
# - **Episode ends**: when the car reaches the goal or after 200 steps.
#
# ---
#
# ## Step 1: Environment and Random Policy (with AI help)
# - Use an **AI tool (e.g., ChatGPT)** to generate starter code for:
#   - Creating the Gym environment (`MountainCar-v0`).
#   - Running a **random policy** (actions chosen randomly).
# - Run this code to confirm you can interact with the environment and see episode returns.
# - This will serve as a **baseline**.
# - **Important**: Do not use AI to implement the learning algorithm.
#
# ---
#
# ## Step 2: SARSA Algorithm with Function Approximation
# Implement **SARSA (on-policy TD control)** with the following steps:
#
# For each episode:
# 1. Initialize state `s`.
# 2. Choose action `a` using **ε-greedy** based on Q(s,a).
# 3. For each step:
#    - Take action `a`, observe `(s_next, r, done)`.
#    - Choose next action `a_next` using ε-greedy from `s_next`.
#    - Compute TD target:
#      ```
#      target = r + gamma * Q(s_next, a_next)
#      ```
#      (if `s_next` is terminal, then target = r).
#    - Compute TD error:
#      ```
#      delta = target - Q(s,a)
#      ```
#    - Update weights:
#      ```
#      w <- w + alpha * delta * x(s,a)
#      ```
#    - Update `s = s_next`, `a = a_next`.
# 4. End episode when the goal is reached or step limit is hit.
#
# ---
#
# ## Step 3: Experiments
# - Train the agent for 500–1000 episodes.
# - Plot **episode returns (sum of rewards)** vs episodes.
# - Compare with the random policy baseline:
#   - Does SARSA learn to consistently reach the goal?
#   - How many steps does it typically take?
#
# ---
#
# ## Deliverables
# - Python code for tile coding and SARSA.
# - Plot of returns vs episodes.
# - Plot the Value function
# - Short discussion (1–2 paragraphs):
#   - Effect of tile coding parameters (number of tilings, resolution).

# %%
# You can use the following code for tiling
import numpy as np


class TileCoderXY:
    """
    A TileCoder for function approximation that applies tile coding on the x and y coordinates
    of a 3D state. Instead of providing tile widths, the user provides the number of tiles per
    dimension. The tile widths are computed based on the state bounds and the number of tiles.
    The z coordinate is not used.
    """

    def __init__(self, num_tilings, tiles_per_dim, state_low, state_high):
        """
        Initialize the TileCoderXY.

        Parameters:
            num_tilings (int): Number of overlapping tilings.
            tiles_per_dim (array-like of 2 ints): Number of tiles along the x and y dimensions.
            state_low (array-like of 2 floats): Lower bounds for the x and y dimensions.
            state_high (array-like of 2 floats): Upper bounds for the x and y dimensions.
        """
        self.num_tilings = num_tilings
        self.tiles_per_dim = np.array(tiles_per_dim, dtype=int)
        self.state_low = np.array(state_low, dtype=float)
        self.state_high = np.array(state_high, dtype=float)

        # Compute the tile width for each dimension.
        # We assume that the grid spans exactly from state_low to state_high.
        # When there are N tiles, there are N-1 intervals between the boundaries.
        self.tile_width = (self.state_high - self.state_low) / (self.tiles_per_dim - 1)

        # Precompute an offset for each tiling to create overlapping grids.
        # self.offsets = [(i / self.num_tilings) * self.tile_width for i in range(self.num_tilings)]
        # self.offsets = self.compute_8_offsets()
        # self.offsets = np.stack(self._compute_offsets(), axis=0)  # shape: (num_tilings, dims)
        # Precompute offsets for each tiling.
        # For tiling i:
        #   offset_x = (((i + 0) % num_tilings) / num_tilings) * tile_width[0]
        #   offset_y = (((i + 1) % num_tilings) / num_tilings) * tile_width[1]
        offsets = np.empty((self.num_tilings, 2))
        for i in range(self.num_tilings):
            offsets[i, 0] = (((i + 0) % self.num_tilings) / self.num_tilings) * self.tile_width[0]
            offsets[i, 1] = (((i + 1) % self.num_tilings) / self.num_tilings) * self.tile_width[1]
        self.offsets = offsets


        # Precompute multiplier for flattening a 2D index.
        # For grid shape (N, M), flat index = x_index * M + y_index.
        self.multiplier = self.tiles_per_dim[1]

        # Initialize a weight vector for each tiling.
        num_tiles = np.prod(self.tiles_per_dim)
        self.weights = [np.zeros(num_tiles) for _ in range(self.num_tilings)]

    def save(self, file_name):
        np.savez(file_name + ".npz", weights=self.weights)

    def load(self, file_name):
        self.weights = np.load(file_name+".npz")["weights"]


    def compute_8_offsets(self):
        """
        Compute a list of offsets using a combination of cardinal and diagonal directions.
        The offsets include:
          - Center: [0, 0]
          - Cardinal: right, left, up, down (half-tile shifts)
          - Diagonal: up-right, up-left, down-right, down-left (half-tile shifts)

        If the number of tilings exceeds the number of unique offsets (9), the list is repeated.

        Returns:
            List of 2-element numpy arrays representing the offset for each tiling.
        """
        half_tile = self.tile_width / 8.0
        base_offsets = [
            np.array([0.0, 0.0]),  # Center (no shift)
            np.array([half_tile[0], 0.0]),  # Right
            np.array([-half_tile[0], 0.0]),  # Left
            np.array([0.0, half_tile[1]]),  # Up
            np.array([0.0, -half_tile[1]]),  # Down
            np.array([half_tile[0], half_tile[1]]),  # Up-right
            np.array([-half_tile[0], half_tile[1]]),  # Up-left
            np.array([half_tile[0], -half_tile[1]]),  # Down-right
            np.array([-half_tile[0], -half_tile[1]])  # Down-left
        ]
        offsets = []
        for i in range(self.num_tilings):
            offsets.append(base_offsets[i % len(base_offsets)])
        return offsets

    def get_tile_indices(self, state):
        """
        Compute the active tile indices for all tilings given a 2D state.

        Parameters:
            state (array-like of length 2): The input state [x, y].

        Returns:
            List of tuples (tiling_index, flat_tile_index) for each tiling.
        """
        state = np.array(state, dtype=float)  # shape: (2,)
        # Compute shifted states for all tilings in one vectorized operation.
        # Shape of shifted: (num_tilings, 2)
        shifted = (state - self.state_low) + self.offsets

        # Compute tile coordinates (integer indices) for each tiling.
        # Division is broadcasted over the offsets.
        tile_coords = (shifted / self.tile_width).astype(int)  # shape: (num_tilings, 2)

        # Clip to ensure indices are within bounds.
        tile_coords[:, 0] = np.clip(tile_coords[:, 0], 0, self.tiles_per_dim[0] - 1)
        tile_coords[:, 1] = np.clip(tile_coords[:, 1], 0, self.tiles_per_dim[1] - 1)

        # Compute flat indices for each tiling.
        # flat_index = x_index * (tiles_per_dim[1]) + y_index
        flat_indices = tile_coords[:, 0] * self.tiles_per_dim[1] + tile_coords[:, 1]

        # Return a list of (tiling_index, flat_index) tuples.
        return list(zip(range(self.num_tilings), flat_indices))


    def predict(self, state):
        """
        Compute the approximated function value for a given 3D state using tile coding on x and y.

        Parameters:
            state (array-like): The input state [x, y, z].

        Returns:
            float: The function approximation (sum of weights for the active tiles).
        """
        active_tiles = self.get_tile_indices(state)
        return sum(self.weights[tiling][idx] for tiling, idx in active_tiles)

    def update(self, state, target, alpha):
        """
        Update the weights given a state and target value.

        Parameters:
            state (array-like): The input state [x, y, z].
            target (float): The target function value.
            alpha (float): The overall learning rate.
        """
        prediction = self.predict(state)
        error = target - prediction
        # Distribute the learning rate equally among all tilings.
        alpha_per_tiling = alpha / self.num_tilings

        active_tiles = self.get_tile_indices(state)
        for tiling, idx in active_tiles:
            self.weights[tiling][idx] += alpha_per_tiling * error

# %%
#reset

#create tileCoder object
left = TileCoderXY(1, (20,20), (-1.2, -0.07), (0.6, 0.07))
nothing = TileCoderXY(1, (20,20), (-1.2, -0.07), (0.6, 0.07))
right = TileCoderXY(1, (20,20), (-1.2, -0.07), (0.6, 0.07))

#create Q array
Q = [left, nothing, right]

# %%
import gymnasium as gym
import numpy as np

# Create the MountainCar environment
env = gym.make('MountainCar-v0', render_mode='ansi')

# Run a random policy
n_episodes = 1000  # You can adjust the number of episodes
n_actions = env.action_space.n
max_steps = 2000
epsilon = 0.01
alpha = 0.1
gamma = 0.99
returns = []

def epsilon_greedy(state):
    """Choose an action using epsilon-greedy policy."""
    if np.random.rand() < epsilon:
        return np.random.randint(n_actions)
    return np.argmax([x.predict(state) for x in Q])

for episode in range(n_episodes):
    state, _ = env.reset()
    total_reward = 0
    done = False
    step = 0

    action = epsilon_greedy(state)
    while not done:
        next_state, reward, done, _, _ = env.step(action)

        target = reward + gamma * Q[action].predict(next_state)
        Q[action].update(state, target, alpha)

        total_reward += reward
        state = next_state
        action = epsilon_greedy(state)

        step += 1
        if step >= max_steps:
          break

    returns.append(total_reward)
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

env.close()
print("\nAverage return over random policy episodes:", np.mean(returns))
# Out:
# C:\Users\lukec\miniconda3\lib\site-packages\gymnasium\envs\registration.py:736: UserWarning: WARN: The environment is being initialised with render_mode='ansi' that is not in the possible render_modes (['human', 'rgb_array']).
#   logger.warn(
# Episode 1: Total Reward = -2000.0
# Episode 2: Total Reward = -2000.0
# Episode 3: Total Reward = -2000.0
# Episode 4: Total Reward = -2000.0
# Episode 5: Total Reward = -2000.0
# Episode 6: Total Reward = -2000.0
# Episode 7: Total Reward = -2000.0
# Episode 8: Total Reward = -2000.0
# Episode 9: Total Reward = -2000.0
# Episode 10: Total Reward = -2000.0
# Episode 11: Total Reward = -2000.0
# Episode 12: Total Reward = -1907.0
# Episode 13: Total Reward = -1541.0
# Episode 14: Total Reward = -2000.0
# Episode 15: Total Reward = -2000.0
# Episode 16: Total Reward = -2000.0
# Episode 17: Total Reward = -2000.0
# Episode 18: Total Reward = -1164.0
# Episode 19: Total Reward = -2000.0
# Episode 20: Total Reward = -2000.0
# Episode 21: Total Reward = -2000.0
# Episode 22: Total Reward = -2000.0
# Episode 23: Total Reward = -912.0
# Episode 24: Total Reward = -2000.0
# Episode 25: Total Reward = -1887.0
# Episode 26: Total Reward = -2000.0
# Episode 27: Total Reward = -2000.0
# Episode 28: Total Reward = -2000.0
# Episode 29: Total Reward = -1515.0
# Episode 30: Total Reward = -2000.0
# Episode 31: Total Reward = -1786.0
# Episode 32: Total Reward = -1374.0
# Episode 33: Total Reward = -1772.0
# Episode 34: Total Reward = -1019.0
# Episode 35: Total Reward = -1948.0
# Episode 36: Total Reward = -864.0
# Episode 37: Total Reward = -1276.0
# Episode 38: Total Reward = -1001.0
# Episode 39: Total Reward = -1567.0
# Episode 40: Total Reward = -1362.0
# Episode 41: Total Reward = -1127.0
# Episode 42: Total Reward = -1256.0
# Episode 43: Total Reward = -850.0
# Episode 44: Total Reward = -888.0
# Episode 45: Total Reward = -1198.0
# Episode 46: Total Reward = -1177.0
# Episode 47: Total Reward = -1434.0
# Episode 48: Total Reward = -936.0
# Episode 49: Total Reward = -753.0
# Episode 50: Total Reward = -883.0
# Episode 51: Total Reward = -617.0
# Episode 52: Total Reward = -1063.0
# Episode 53: Total Reward = -815.0
# Episode 54: Total Reward = -940.0
# Episode 55: Total Reward = -662.0
# Episode 56: Total Reward = -879.0
# Episode 57: Total Reward = -1979.0
# Episode 58: Total Reward = -1779.0
# Episode 59: Total Reward = -933.0
# Episode 60: Total Reward = -621.0
# Episode 61: Total Reward = -705.0
# Episode 62: Total Reward = -868.0
# Episode 63: Total Reward = -484.0
# Episode 64: Total Reward = -404.0
# Episode 65: Total Reward = -450.0
# Episode 66: Total Reward = -442.0
# Episode 67: Total Reward = -742.0
# Episode 68: Total Reward = -522.0
# Episode 69: Total Reward = -431.0
# Episode 70: Total Reward = -416.0
# Episode 71: Total Reward = -694.0
# Episode 72: Total Reward = -524.0
# Episode 73: Total Reward = -436.0
# Episode 74: Total Reward = -579.0
# Episode 75: Total Reward = -399.0
# Episode 76: Total Reward = -358.0
# Episode 77: Total Reward = -684.0
# Episode 78: Total Reward = -664.0
# Episode 79: Total Reward = -590.0
# Episode 80: Total Reward = -712.0
# Episode 81: Total Reward = -509.0
# Episode 82: Total Reward = -345.0
# Episode 83: Total Reward = -350.0
# Episode 84: Total Reward = -574.0
# Episode 85: Total Reward = -431.0
# Episode 86: Total Reward = -467.0
# Episode 87: Total Reward = -359.0
# Episode 88: Total Reward = -459.0
# Episode 89: Total Reward = -461.0
# Episode 90: Total Reward = -589.0
# Episode 91: Total Reward = -546.0
# Episode 92: Total Reward = -461.0
# Episode 93: Total Reward = -537.0
# Episode 94: Total Reward = -456.0
# Episode 95: Total Reward = -380.0
# Episode 96: Total Reward = -435.0
# Episode 97: Total Reward = -422.0
# Episode 98: Total Reward = -367.0
# Episode 99: Total Reward = -263.0
# Episode 100: Total Reward = -449.0
# Episode 101: Total Reward = -498.0
# Episode 102: Total Reward = -439.0
# Episode 103: Total Reward = -326.0
# Episode 104: Total Reward = -286.0
# Episode 105: Total Reward = -590.0
# Episode 106: Total Reward = -366.0
# Episode 107: Total Reward = -447.0
# Episode 108: Total Reward = -565.0
# Episode 109: Total Reward = -921.0
# Episode 110: Total Reward = -1223.0
# Episode 111: Total Reward = -1365.0
# Episode 112: Total Reward = -516.0
# Episode 113: Total Reward = -320.0
# Episode 114: Total Reward = -368.0
# Episode 115: Total Reward = -384.0
# Episode 116: Total Reward = -364.0
# Episode 117: Total Reward = -366.0
# Episode 118: Total Reward = -443.0
# Episode 119: Total Reward = -444.0
# Episode 120: Total Reward = -524.0
# Episode 121: Total Reward = -355.0
# Episode 122: Total Reward = -392.0
# Episode 123: Total Reward = -344.0
# Episode 124: Total Reward = -539.0
# Episode 125: Total Reward = -425.0
# Episode 126: Total Reward = -403.0
# Episode 127: Total Reward = -275.0
# Episode 128: Total Reward = -270.0
# Episode 129: Total Reward = -247.0
# Episode 130: Total Reward = -204.0
# Episode 131: Total Reward = -405.0
# Episode 132: Total Reward = -364.0
# Episode 133: Total Reward = -328.0
# Episode 134: Total Reward = -286.0
# Episode 135: Total Reward = -355.0
# Episode 136: Total Reward = -285.0
# Episode 137: Total Reward = -376.0
# Episode 138: Total Reward = -267.0
# Episode 139: Total Reward = -255.0
# Episode 140: Total Reward = -275.0
# Episode 141: Total Reward = -280.0
# Episode 142: Total Reward = -289.0
# Episode 143: Total Reward = -263.0
# Episode 144: Total Reward = -371.0
# Episode 145: Total Reward = -294.0
# Episode 146: Total Reward = -274.0
# Episode 147: Total Reward = -443.0
# Episode 148: Total Reward = -344.0
# Episode 149: Total Reward = -277.0
# Episode 150: Total Reward = -343.0
# Episode 151: Total Reward = -403.0
# Episode 152: Total Reward = -375.0
# Episode 153: Total Reward = -371.0
# Episode 154: Total Reward = -318.0
# Episode 155: Total Reward = -342.0
# Episode 156: Total Reward = -273.0
# Episode 157: Total Reward = -360.0
# Episode 158: Total Reward = -284.0
# Episode 159: Total Reward = -475.0
# Episode 160: Total Reward = -366.0
# Episode 161: Total Reward = -268.0
# Episode 162: Total Reward = -284.0
# Episode 163: Total Reward = -282.0
# Episode 164: Total Reward = -399.0
# Episode 165: Total Reward = -255.0
# Episode 166: Total Reward = -314.0
# Episode 167: Total Reward = -252.0
# Episode 168: Total Reward = -278.0
# Episode 169: Total Reward = -272.0
# Episode 170: Total Reward = -257.0
# Episode 171: Total Reward = -429.0
# Episode 172: Total Reward = -457.0
# Episode 173: Total Reward = -342.0
# Episode 174: Total Reward = -326.0
# Episode 175: Total Reward = -274.0
# Episode 176: Total Reward = -402.0
# Episode 177: Total Reward = -293.0
# Episode 178: Total Reward = -206.0
# Episode 179: Total Reward = -333.0
# Episode 180: Total Reward = -335.0
# Episode 181: Total Reward = -256.0
# Episode 182: Total Reward = -313.0
# Episode 183: Total Reward = -379.0
# Episode 184: Total Reward = -336.0
# Episode 185: Total Reward = -343.0
# Episode 186: Total Reward = -375.0
# Episode 187: Total Reward = -270.0
# Episode 188: Total Reward = -282.0
# Episode 189: Total Reward = -323.0
# Episode 190: Total Reward = -242.0
# Episode 191: Total Reward = -277.0
# Episode 192: Total Reward = -330.0
# Episode 193: Total Reward = -292.0
# Episode 194: Total Reward = -318.0
# Episode 195: Total Reward = -287.0
# Episode 196: Total Reward = -347.0
# Episode 197: Total Reward = -445.0
# Episode 198: Total Reward = -354.0
# Episode 199: Total Reward = -207.0
# Episode 200: Total Reward = -244.0
# Episode 201: Total Reward = -280.0
# Episode 202: Total Reward = -357.0
# Episode 203: Total Reward = -353.0
# Episode 204: Total Reward = -317.0
# Episode 205: Total Reward = -348.0
# Episode 206: Total Reward = -242.0
# Episode 207: Total Reward = -196.0
# Episode 208: Total Reward = -190.0
# Episode 209: Total Reward = -309.0
# Episode 210: Total Reward = -275.0
# Episode 211: Total Reward = -265.0
# Episode 212: Total Reward = -266.0
# Episode 213: Total Reward = -280.0
# Episode 214: Total Reward = -179.0
# Episode 215: Total Reward = -273.0
# Episode 216: Total Reward = -189.0
# Episode 217: Total Reward = -188.0
# Episode 218: Total Reward = -267.0
# Episode 219: Total Reward = -304.0
# Episode 220: Total Reward = -268.0
# Episode 221: Total Reward = -280.0
# Episode 222: Total Reward = -272.0
# Episode 223: Total Reward = -264.0
# Episode 224: Total Reward = -294.0
# Episode 225: Total Reward = -189.0
# Episode 226: Total Reward = -284.0
# Episode 227: Total Reward = -279.0
# Episode 228: Total Reward = -235.0
# Episode 229: Total Reward = -245.0
# Episode 230: Total Reward = -351.0
# Episode 231: Total Reward = -286.0
# Episode 232: Total Reward = -272.0
# Episode 233: Total Reward = -432.0
# Episode 234: Total Reward = -266.0
# Episode 235: Total Reward = -416.0
# Episode 236: Total Reward = -198.0
# Episode 237: Total Reward = -197.0
# Episode 238: Total Reward = -268.0
# Episode 239: Total Reward = -419.0
# Episode 240: Total Reward = -272.0
# Episode 241: Total Reward = -297.0
# Episode 242: Total Reward = -265.0
# Episode 243: Total Reward = -259.0
# Episode 244: Total Reward = -200.0
# Episode 245: Total Reward = -232.0
# Episode 246: Total Reward = -274.0
# Episode 247: Total Reward = -231.0
# Episode 248: Total Reward = -187.0
# Episode 249: Total Reward = -225.0
# Episode 250: Total Reward = -187.0
# Episode 251: Total Reward = -270.0
# Episode 252: Total Reward = -192.0
# Episode 253: Total Reward = -262.0
# Episode 254: Total Reward = -195.0
# Episode 255: Total Reward = -266.0
# Episode 256: Total Reward = -189.0
# Episode 257: Total Reward = -188.0
# Episode 258: Total Reward = -196.0
# Episode 259: Total Reward = -315.0
# Episode 260: Total Reward = -191.0
# Episode 261: Total Reward = -186.0
# Episode 262: Total Reward = -269.0
# Episode 263: Total Reward = -225.0
# Episode 264: Total Reward = -284.0
# Episode 265: Total Reward = -319.0
# Episode 266: Total Reward = -258.0
# Episode 267: Total Reward = -274.0
# Episode 268: Total Reward = -424.0
# Episode 269: Total Reward = -275.0
# Episode 270: Total Reward = -365.0
# Episode 271: Total Reward = -278.0
# Episode 272: Total Reward = -263.0
# Episode 273: Total Reward = -433.0
# Episode 274: Total Reward = -276.0
# Episode 275: Total Reward = -316.0
# Episode 276: Total Reward = -362.0
# Episode 277: Total Reward = -501.0
# Episode 278: Total Reward = -257.0
# Episode 279: Total Reward = -329.0
# Episode 280: Total Reward = -341.0
# Episode 281: Total Reward = -274.0
# Episode 282: Total Reward = -315.0
# Episode 283: Total Reward = -256.0
# Episode 284: Total Reward = -233.0
# Episode 285: Total Reward = -422.0
# Episode 286: Total Reward = -260.0
# Episode 287: Total Reward = -273.0
# Episode 288: Total Reward = -257.0
# Episode 289: Total Reward = -269.0
# Episode 290: Total Reward = -266.0
# Episode 291: Total Reward = -350.0
# Episode 292: Total Reward = -343.0
# Episode 293: Total Reward = -233.0
# Episode 294: Total Reward = -267.0
# Episode 295: Total Reward = -252.0
# Episode 296: Total Reward = -265.0
# Episode 297: Total Reward = -346.0
# Episode 298: Total Reward = -255.0
# Episode 299: Total Reward = -252.0
# Episode 300: Total Reward = -318.0
# Episode 301: Total Reward = -222.0
# Episode 302: Total Reward = -197.0
# Episode 303: Total Reward = -260.0
# Episode 304: Total Reward = -264.0
# Episode 305: Total Reward = -190.0
# Episode 306: Total Reward = -273.0
# Episode 307: Total Reward = -235.0
# Episode 308: Total Reward = -242.0
# Episode 309: Total Reward = -249.0
# Episode 310: Total Reward = -205.0
# Episode 311: Total Reward = -195.0
# Episode 312: Total Reward = -195.0
# Episode 313: Total Reward = -196.0
# Episode 314: Total Reward = -279.0
# Episode 315: Total Reward = -261.0
# Episode 316: Total Reward = -309.0
# Episode 317: Total Reward = -291.0
# Episode 318: Total Reward = -288.0
# Episode 319: Total Reward = -283.0
# Episode 320: Total Reward = -197.0
# Episode 321: Total Reward = -279.0
# Episode 322: Total Reward = -256.0
# Episode 323: Total Reward = -317.0
# Episode 324: Total Reward = -164.0
# Episode 325: Total Reward = -195.0
# Episode 326: Total Reward = -194.0
# Episode 327: Total Reward = -278.0
# Episode 328: Total Reward = -285.0
# Episode 329: Total Reward = -294.0
# Episode 330: Total Reward = -498.0
# Episode 331: Total Reward = -203.0
# Episode 332: Total Reward = -422.0
# Episode 333: Total Reward = -298.0
# Episode 334: Total Reward = -463.0
# Episode 335: Total Reward = -203.0
# Episode 336: Total Reward = -560.0
# Episode 337: Total Reward = -298.0
# Episode 338: Total Reward = -297.0
# Episode 339: Total Reward = -277.0
# Episode 340: Total Reward = -367.0
# Episode 341: Total Reward = -200.0
# Episode 342: Total Reward = -500.0
# Episode 343: Total Reward = -380.0
# Episode 344: Total Reward = -312.0
# Episode 345: Total Reward = -197.0
# Episode 346: Total Reward = -251.0
# Episode 347: Total Reward = -250.0
# Episode 348: Total Reward = -382.0
# Episode 349: Total Reward = -335.0
# Episode 350: Total Reward = -282.0
# Episode 351: Total Reward = -278.0
# Episode 352: Total Reward = -309.0
# Episode 353: Total Reward = -579.0
# Episode 354: Total Reward = -294.0
# Episode 355: Total Reward = -559.0
# Episode 356: Total Reward = -208.0
# Episode 357: Total Reward = -214.0
# Episode 358: Total Reward = -374.0
# Episode 359: Total Reward = -453.0
# Episode 360: Total Reward = -537.0
# Episode 361: Total Reward = -243.0
# Episode 362: Total Reward = -277.0
# Episode 363: Total Reward = -278.0
# Episode 364: Total Reward = -284.0
# Episode 365: Total Reward = -285.0
# Episode 366: Total Reward = -640.0
# Episode 367: Total Reward = -284.0
# Episode 368: Total Reward = -327.0
# Episode 369: Total Reward = -198.0
# Episode 370: Total Reward = -295.0
# Episode 371: Total Reward = -390.0
# Episode 372: Total Reward = -317.0
# Episode 373: Total Reward = -271.0
# Episode 374: Total Reward = -259.0
# Episode 375: Total Reward = -283.0
# Episode 376: Total Reward = -231.0
# Episode 377: Total Reward = -268.0
# Episode 378: Total Reward = -394.0
# Episode 379: Total Reward = -394.0
# Episode 380: Total Reward = -207.0
# Episode 381: Total Reward = -194.0
# Episode 382: Total Reward = -279.0
# Episode 383: Total Reward = -264.0
# Episode 384: Total Reward = -271.0
# Episode 385: Total Reward = -243.0
# Episode 386: Total Reward = -359.0
# Episode 387: Total Reward = -229.0
# Episode 388: Total Reward = -355.0
# Episode 389: Total Reward = -520.0
# Episode 390: Total Reward = -199.0
# Episode 391: Total Reward = -490.0
# Episode 392: Total Reward = -390.0
# Episode 393: Total Reward = -545.0
# Episode 394: Total Reward = -969.0
# Episode 395: Total Reward = -379.0
# Episode 396: Total Reward = -402.0
# Episode 397: Total Reward = -365.0
# Episode 398: Total Reward = -256.0
# Episode 399: Total Reward = -353.0
# Episode 400: Total Reward = -446.0
# Episode 401: Total Reward = -255.0
# Episode 402: Total Reward = -205.0
# Episode 403: Total Reward = -449.0
# Episode 404: Total Reward = -264.0
# Episode 405: Total Reward = -634.0
# Episode 406: Total Reward = -214.0
# Episode 407: Total Reward = -563.0
# Episode 408: Total Reward = -647.0
# Episode 409: Total Reward = -282.0
# Episode 410: Total Reward = -302.0
# Episode 411: Total Reward = -437.0
# Episode 412: Total Reward = -446.0
# Episode 413: Total Reward = -459.0
# Episode 414: Total Reward = -245.0
# Episode 415: Total Reward = -1200.0
# Episode 416: Total Reward = -370.0
# Episode 417: Total Reward = -202.0
# Episode 418: Total Reward = -448.0
# Episode 419: Total Reward = -285.0
# Episode 420: Total Reward = -465.0
# Episode 421: Total Reward = -487.0
# Episode 422: Total Reward = -255.0
# Episode 423: Total Reward = -740.0
# Episode 424: Total Reward = -425.0
# Episode 425: Total Reward = -556.0
# Episode 426: Total Reward = -309.0
# Episode 427: Total Reward = -1158.0
# Episode 428: Total Reward = -1021.0
# Episode 429: Total Reward = -1687.0
# Episode 430: Total Reward = -1117.0
# Episode 431: Total Reward = -255.0
# Episode 432: Total Reward = -613.0
# Episode 433: Total Reward = -1556.0
# Episode 434: Total Reward = -213.0
# Episode 435: Total Reward = -212.0
# Episode 436: Total Reward = -416.0
# Episode 437: Total Reward = -544.0
# Episode 438: Total Reward = -340.0
# Episode 439: Total Reward = -258.0
# Episode 440: Total Reward = -259.0
# Episode 441: Total Reward = -680.0
# Episode 442: Total Reward = -266.0
# Episode 443: Total Reward = -309.0
# Episode 444: Total Reward = -234.0
# Episode 445: Total Reward = -236.0
# Episode 446: Total Reward = -364.0
# Episode 447: Total Reward = -197.0
# Episode 448: Total Reward = -282.0
# Episode 449: Total Reward = -278.0
# Episode 450: Total Reward = -290.0
# Episode 451: Total Reward = -194.0
# Episode 452: Total Reward = -193.0
# Episode 453: Total Reward = -192.0
# Episode 454: Total Reward = -282.0
# Episode 455: Total Reward = -283.0
# Episode 456: Total Reward = -279.0
# Episode 457: Total Reward = -540.0
# Episode 458: Total Reward = -470.0
# Episode 459: Total Reward = -278.0
# Episode 460: Total Reward = -282.0
# Episode 461: Total Reward = -283.0
# Episode 462: Total Reward = -303.0
# Episode 463: Total Reward = -290.0
# Episode 464: Total Reward = -582.0
# Episode 465: Total Reward = -196.0
# Episode 466: Total Reward = -281.0
# Episode 467: Total Reward = -249.0
# Episode 468: Total Reward = -281.0
# Episode 469: Total Reward = -287.0
# Episode 470: Total Reward = -334.0
# Episode 471: Total Reward = -195.0
# Episode 472: Total Reward = -242.0
# Episode 473: Total Reward = -456.0
# Episode 474: Total Reward = -341.0
# Episode 475: Total Reward = -285.0
# Episode 476: Total Reward = -258.0
# Episode 477: Total Reward = -273.0
# Episode 478: Total Reward = -282.0
# Episode 479: Total Reward = -277.0
# Episode 480: Total Reward = -275.0
# Episode 481: Total Reward = -277.0
# Episode 482: Total Reward = -270.0
# Episode 483: Total Reward = -185.0
# Episode 484: Total Reward = -363.0
# Episode 485: Total Reward = -277.0
# Episode 486: Total Reward = -360.0
# Episode 487: Total Reward = -246.0
# Episode 488: Total Reward = -280.0
# Episode 489: Total Reward = -342.0
# Episode 490: Total Reward = -270.0
# Episode 491: Total Reward = -241.0
# Episode 492: Total Reward = -235.0
# Episode 493: Total Reward = -370.0
# Episode 494: Total Reward = -240.0
# Episode 495: Total Reward = -325.0
# Episode 496: Total Reward = -330.0
# Episode 497: Total Reward = -238.0
# Episode 498: Total Reward = -440.0
# Episode 499: Total Reward = -242.0
# Episode 500: Total Reward = -233.0
# Episode 501: Total Reward = -331.0
# Episode 502: Total Reward = -243.0
# Episode 503: Total Reward = -238.0
# Episode 504: Total Reward = -476.0
# Episode 505: Total Reward = -234.0
# Episode 506: Total Reward = -229.0
# Episode 507: Total Reward = -239.0
# Episode 508: Total Reward = -319.0
# Episode 509: Total Reward = -232.0
# Episode 510: Total Reward = -412.0
# Episode 511: Total Reward = -321.0
# Episode 512: Total Reward = -230.0
# Episode 513: Total Reward = -229.0
# Episode 514: Total Reward = -242.0
# Episode 515: Total Reward = -238.0
# Episode 516: Total Reward = -245.0
# Episode 517: Total Reward = -253.0
# Episode 518: Total Reward = -246.0
# Episode 519: Total Reward = -239.0
# Episode 520: Total Reward = -324.0
# Episode 521: Total Reward = -236.0
# Episode 522: Total Reward = -247.0
# Episode 523: Total Reward = -239.0
# Episode 524: Total Reward = -247.0
# Episode 525: Total Reward = -238.0
# Episode 526: Total Reward = -247.0
# Episode 527: Total Reward = -239.0
# Episode 528: Total Reward = -323.0
# Episode 529: Total Reward = -232.0
# Episode 530: Total Reward = -235.0
# Episode 531: Total Reward = -329.0
# Episode 532: Total Reward = -215.0
# Episode 533: Total Reward = -223.0
# Episode 534: Total Reward = -138.0
# Episode 535: Total Reward = -214.0
# Episode 536: Total Reward = -327.0
# Episode 537: Total Reward = -233.0
# Episode 538: Total Reward = -237.0
# Episode 539: Total Reward = -215.0
# Episode 540: Total Reward = -231.0
# Episode 541: Total Reward = -238.0
# Episode 542: Total Reward = -325.0
# Episode 543: Total Reward = -221.0
# Episode 544: Total Reward = -225.0
# Episode 545: Total Reward = -220.0
# Episode 546: Total Reward = -239.0
# Episode 547: Total Reward = -233.0
# Episode 548: Total Reward = -217.0
# Episode 549: Total Reward = -250.0
# Episode 550: Total Reward = -162.0
# Episode 551: Total Reward = -238.0
# Episode 552: Total Reward = -308.0
# Episode 553: Total Reward = -194.0
# Episode 554: Total Reward = -236.0
# Episode 555: Total Reward = -320.0
# Episode 556: Total Reward = -334.0
# Episode 557: Total Reward = -215.0
# Episode 558: Total Reward = -238.0
# Episode 559: Total Reward = -237.0
# Episode 560: Total Reward = -236.0
# Episode 561: Total Reward = -240.0
# Episode 562: Total Reward = -238.0
# Episode 563: Total Reward = -194.0
# Episode 564: Total Reward = -310.0
# Episode 565: Total Reward = -222.0
# Episode 566: Total Reward = -241.0
# Episode 567: Total Reward = -206.0
# Episode 568: Total Reward = -226.0
# Episode 569: Total Reward = -218.0
# Episode 570: Total Reward = -318.0
# Episode 571: Total Reward = -302.0
# Episode 572: Total Reward = -297.0
# Episode 573: Total Reward = -186.0
# Episode 574: Total Reward = -210.0
# Episode 575: Total Reward = -190.0
# Episode 576: Total Reward = -192.0
# Episode 577: Total Reward = -212.0
# Episode 578: Total Reward = -288.0
# Episode 579: Total Reward = -315.0
# Episode 580: Total Reward = -206.0
# Episode 581: Total Reward = -231.0
# Episode 582: Total Reward = -226.0
# Episode 583: Total Reward = -213.0
# Episode 584: Total Reward = -190.0
# Episode 585: Total Reward = -296.0
# Episode 586: Total Reward = -251.0
# Episode 587: Total Reward = -313.0
# Episode 588: Total Reward = -299.0
# Episode 589: Total Reward = -162.0
# Episode 590: Total Reward = -203.0
# Episode 591: Total Reward = -346.0
# Episode 592: Total Reward = -208.0
# Episode 593: Total Reward = -209.0
# Episode 594: Total Reward = -224.0
# Episode 595: Total Reward = -200.0
# Episode 596: Total Reward = -152.0
# Episode 597: Total Reward = -243.0
# Episode 598: Total Reward = -161.0
# Episode 599: Total Reward = -168.0
# Episode 600: Total Reward = -197.0
# Episode 601: Total Reward = -237.0
# Episode 602: Total Reward = -166.0
# Episode 603: Total Reward = -156.0
# Episode 604: Total Reward = -232.0
# Episode 605: Total Reward = -242.0
# Episode 606: Total Reward = -243.0
# Episode 607: Total Reward = -242.0
# Episode 608: Total Reward = -159.0
# Episode 609: Total Reward = -241.0
# Episode 610: Total Reward = -205.0
# Episode 611: Total Reward = -200.0
# Episode 612: Total Reward = -151.0
# Episode 613: Total Reward = -252.0
# Episode 614: Total Reward = -200.0
# Episode 615: Total Reward = -202.0
# Episode 616: Total Reward = -197.0
# Episode 617: Total Reward = -235.0
# Episode 618: Total Reward = -190.0
# Episode 619: Total Reward = -150.0
# Episode 620: Total Reward = -240.0
# Episode 621: Total Reward = -146.0
# Episode 622: Total Reward = -155.0
# Episode 623: Total Reward = -199.0
# Episode 624: Total Reward = -203.0
# Episode 625: Total Reward = -233.0
# Episode 626: Total Reward = -238.0
# Episode 627: Total Reward = -250.0
# Episode 628: Total Reward = -289.0
# Episode 629: Total Reward = -279.0
# Episode 630: Total Reward = -228.0
# Episode 631: Total Reward = -272.0
# Episode 632: Total Reward = -227.0
# Episode 633: Total Reward = -267.0
# Episode 634: Total Reward = -229.0
# Episode 635: Total Reward = -306.0
# Episode 636: Total Reward = -231.0
# Episode 637: Total Reward = -157.0
# Episode 638: Total Reward = -232.0
# Episode 639: Total Reward = -317.0
# Episode 640: Total Reward = -228.0
# Episode 641: Total Reward = -226.0
# Episode 642: Total Reward = -161.0
# Episode 643: Total Reward = -158.0
# Episode 644: Total Reward = -163.0
# Episode 645: Total Reward = -233.0
# Episode 646: Total Reward = -155.0
# Episode 647: Total Reward = -227.0
# Episode 648: Total Reward = -156.0
# Episode 649: Total Reward = -220.0
# Episode 650: Total Reward = -337.0
# Episode 651: Total Reward = -239.0
# Episode 652: Total Reward = -212.0
# Episode 653: Total Reward = -173.0
# Episode 654: Total Reward = -236.0
# Episode 655: Total Reward = -240.0
# Episode 656: Total Reward = -225.0
# Episode 657: Total Reward = -342.0
# Episode 658: Total Reward = -233.0
# Episode 659: Total Reward = -237.0
# Episode 660: Total Reward = -377.0
# Episode 661: Total Reward = -241.0
# Episode 662: Total Reward = -397.0
# Episode 663: Total Reward = -204.0
# Episode 664: Total Reward = -160.0
# Episode 665: Total Reward = -280.0
# Episode 666: Total Reward = -251.0
# Episode 667: Total Reward = -258.0
# Episode 668: Total Reward = -242.0
# Episode 669: Total Reward = -292.0
# Episode 670: Total Reward = -290.0
# Episode 671: Total Reward = -199.0
# Episode 672: Total Reward = -390.0
# Episode 673: Total Reward = -198.0
# Episode 674: Total Reward = -232.0
# Episode 675: Total Reward = -235.0
# Episode 676: Total Reward = -239.0
# Episode 677: Total Reward = -242.0
# Episode 678: Total Reward = -227.0
# Episode 679: Total Reward = -194.0
# Episode 680: Total Reward = -185.0
# Episode 681: Total Reward = -226.0
# Episode 682: Total Reward = -235.0
# Episode 683: Total Reward = -236.0
# Episode 684: Total Reward = -189.0
# Episode 685: Total Reward = -167.0
# Episode 686: Total Reward = -265.0
# Episode 687: Total Reward = -169.0
# Episode 688: Total Reward = -236.0
# Episode 689: Total Reward = -168.0
# Episode 690: Total Reward = -236.0
# Episode 691: Total Reward = -171.0
# Episode 692: Total Reward = -242.0
# Episode 693: Total Reward = -237.0
# Episode 694: Total Reward = -242.0
# Episode 695: Total Reward = -190.0
# Episode 696: Total Reward = -305.0
# Episode 697: Total Reward = -279.0
# Episode 698: Total Reward = -234.0
# Episode 699: Total Reward = -234.0
# Episode 700: Total Reward = -227.0
# Episode 701: Total Reward = -229.0
# Episode 702: Total Reward = -187.0
# Episode 703: Total Reward = -303.0
# Episode 704: Total Reward = -284.0
# Episode 705: Total Reward = -224.0
# Episode 706: Total Reward = -191.0
# Episode 707: Total Reward = -391.0
# Episode 708: Total Reward = -130.0
# Episode 709: Total Reward = -235.0
# Episode 710: Total Reward = -197.0
# Episode 711: Total Reward = -229.0
# Episode 712: Total Reward = -225.0
# Episode 713: Total Reward = -294.0
# Episode 714: Total Reward = -226.0
# Episode 715: Total Reward = -232.0
# Episode 716: Total Reward = -225.0
# Episode 717: Total Reward = -280.0
# Episode 718: Total Reward = -233.0
# Episode 719: Total Reward = -224.0
# Episode 720: Total Reward = -266.0
# Episode 721: Total Reward = -192.0
# Episode 722: Total Reward = -226.0
# Episode 723: Total Reward = -501.0
# Episode 724: Total Reward = -198.0
# Episode 725: Total Reward = -191.0
# Episode 726: Total Reward = -190.0
# Episode 727: Total Reward = -194.0
# Episode 728: Total Reward = -158.0
# Episode 729: Total Reward = -151.0
# Episode 730: Total Reward = -154.0
# Episode 731: Total Reward = -281.0
# Episode 732: Total Reward = -320.0
# Episode 733: Total Reward = -299.0
# Episode 734: Total Reward = -186.0
# Episode 735: Total Reward = -221.0
# Episode 736: Total Reward = -210.0
# Episode 737: Total Reward = -148.0
# Episode 738: Total Reward = -217.0
# Episode 739: Total Reward = -212.0
# Episode 740: Total Reward = -214.0
# Episode 741: Total Reward = -191.0
# Episode 742: Total Reward = -221.0
# Episode 743: Total Reward = -194.0
# Episode 744: Total Reward = -187.0
# Episode 745: Total Reward = -214.0
# Episode 746: Total Reward = -194.0
# Episode 747: Total Reward = -233.0
# Episode 748: Total Reward = -223.0
# Episode 749: Total Reward = -189.0
# Episode 750: Total Reward = -159.0
# Episode 751: Total Reward = -288.0
# Episode 752: Total Reward = -151.0
# Episode 753: Total Reward = -151.0
# Episode 754: Total Reward = -182.0
# Episode 755: Total Reward = -184.0
# Episode 756: Total Reward = -174.0
# Episode 757: Total Reward = -262.0
# Episode 758: Total Reward = -213.0
# Episode 759: Total Reward = -214.0
# Episode 760: Total Reward = -223.0
# Episode 761: Total Reward = -146.0
# Episode 762: Total Reward = -152.0
# Episode 763: Total Reward = -157.0
# Episode 764: Total Reward = -164.0
# Episode 765: Total Reward = -153.0
# Episode 766: Total Reward = -175.0
# Episode 767: Total Reward = -149.0
# Episode 768: Total Reward = -151.0
# Episode 769: Total Reward = -147.0
# Episode 770: Total Reward = -152.0
# Episode 771: Total Reward = -211.0
# Episode 772: Total Reward = -183.0
# Episode 773: Total Reward = -152.0
# Episode 774: Total Reward = -149.0
# Episode 775: Total Reward = -189.0
# Episode 776: Total Reward = -146.0
# Episode 777: Total Reward = -296.0
# Episode 778: Total Reward = -143.0
# Episode 779: Total Reward = -154.0
# Episode 780: Total Reward = -230.0
# Episode 781: Total Reward = -187.0
# Episode 782: Total Reward = -157.0
# Episode 783: Total Reward = -190.0
# Episode 784: Total Reward = -189.0
# Episode 785: Total Reward = -154.0
# Episode 786: Total Reward = -189.0
# Episode 787: Total Reward = -156.0
# Episode 788: Total Reward = -153.0
# Episode 789: Total Reward = -155.0
# Episode 790: Total Reward = -151.0
# Episode 791: Total Reward = -159.0
# Episode 792: Total Reward = -155.0
# Episode 793: Total Reward = -153.0
# Episode 794: Total Reward = -192.0
# Episode 795: Total Reward = -139.0
# Episode 796: Total Reward = -151.0
# Episode 797: Total Reward = -147.0
# Episode 798: Total Reward = -142.0
# Episode 799: Total Reward = -138.0
# Episode 800: Total Reward = -186.0
# Episode 801: Total Reward = -141.0
# Episode 802: Total Reward = -150.0
# Episode 803: Total Reward = -149.0
# Episode 804: Total Reward = -267.0
# Episode 805: Total Reward = -149.0
# Episode 806: Total Reward = -155.0
# Episode 807: Total Reward = -138.0
# Episode 808: Total Reward = -167.0
# Episode 809: Total Reward = -151.0
# Episode 810: Total Reward = -207.0
# Episode 811: Total Reward = -158.0
# Episode 812: Total Reward = -218.0
# Episode 813: Total Reward = -225.0
# Episode 814: Total Reward = -229.0
# Episode 815: Total Reward = -153.0
# Episode 816: Total Reward = -156.0
# Episode 817: Total Reward = -279.0
# Episode 818: Total Reward = -219.0
# Episode 819: Total Reward = -195.0
# Episode 820: Total Reward = -234.0
# Episode 821: Total Reward = -233.0
# Episode 822: Total Reward = -149.0
# Episode 823: Total Reward = -141.0
# Episode 824: Total Reward = -226.0
# Episode 825: Total Reward = -237.0
# Episode 826: Total Reward = -239.0
# Episode 827: Total Reward = -213.0
# Episode 828: Total Reward = -197.0
# Episode 829: Total Reward = -233.0
# Episode 830: Total Reward = -273.0
# Episode 831: Total Reward = -228.0
# Episode 832: Total Reward = -206.0
# Episode 833: Total Reward = -145.0
# Episode 834: Total Reward = -193.0
# Episode 835: Total Reward = -203.0
# Episode 836: Total Reward = -156.0
# Episode 837: Total Reward = -151.0
# Episode 838: Total Reward = -151.0
# Episode 839: Total Reward = -116.0
# Episode 840: Total Reward = -153.0
# Episode 841: Total Reward = -146.0
# Episode 842: Total Reward = -228.0
# Episode 843: Total Reward = -196.0
# Episode 844: Total Reward = -148.0
# Episode 845: Total Reward = -228.0
# Episode 846: Total Reward = -226.0
# Episode 847: Total Reward = -236.0
# Episode 848: Total Reward = -191.0
# Episode 849: Total Reward = -216.0
# Episode 850: Total Reward = -158.0
# Episode 851: Total Reward = -238.0
# Episode 852: Total Reward = -189.0
# Episode 853: Total Reward = -259.0
# Episode 854: Total Reward = -229.0
# Episode 855: Total Reward = -227.0
# Episode 856: Total Reward = -226.0
# Episode 857: Total Reward = -227.0
# Episode 858: Total Reward = -222.0
# Episode 859: Total Reward = -222.0
# Episode 860: Total Reward = -240.0
# Episode 861: Total Reward = -231.0
# Episode 862: Total Reward = -323.0
# Episode 863: Total Reward = -419.0
# Episode 864: Total Reward = -209.0
# Episode 865: Total Reward = -233.0
# Episode 866: Total Reward = -188.0
# Episode 867: Total Reward = -247.0
# Episode 868: Total Reward = -228.0
# Episode 869: Total Reward = -176.0
# Episode 870: Total Reward = -181.0
# Episode 871: Total Reward = -157.0
# Episode 872: Total Reward = -234.0
# Episode 873: Total Reward = -252.0
# Episode 874: Total Reward = -163.0
# Episode 875: Total Reward = -124.0
# Episode 876: Total Reward = -162.0
# Episode 877: Total Reward = -212.0
# Episode 878: Total Reward = -120.0
# Episode 879: Total Reward = -247.0
# Episode 880: Total Reward = -183.0
# Episode 881: Total Reward = -179.0
# Episode 882: Total Reward = -179.0
# Episode 883: Total Reward = -178.0
# Episode 884: Total Reward = -176.0
# Episode 885: Total Reward = -186.0
# Episode 886: Total Reward = -194.0
# Episode 887: Total Reward = -143.0
# Episode 888: Total Reward = -173.0
# Episode 889: Total Reward = -175.0
# Episode 890: Total Reward = -189.0
# Episode 891: Total Reward = -203.0
# Episode 892: Total Reward = -169.0
# Episode 893: Total Reward = -255.0
# Episode 894: Total Reward = -250.0
# Episode 895: Total Reward = -178.0
# Episode 896: Total Reward = -158.0
# Episode 897: Total Reward = -176.0
# Episode 898: Total Reward = -151.0
# Episode 899: Total Reward = -182.0
# Episode 900: Total Reward = -148.0
# Episode 901: Total Reward = -179.0
# Episode 902: Total Reward = -166.0
# Episode 903: Total Reward = -184.0
# Episode 904: Total Reward = -189.0
# Episode 905: Total Reward = -181.0
# Episode 906: Total Reward = -181.0
# Episode 907: Total Reward = -183.0
# Episode 908: Total Reward = -150.0
# Episode 909: Total Reward = -166.0
# Episode 910: Total Reward = -146.0
# Episode 911: Total Reward = -168.0
# Episode 912: Total Reward = -180.0
# Episode 913: Total Reward = -190.0
# Episode 914: Total Reward = -146.0
# Episode 915: Total Reward = -143.0
# Episode 916: Total Reward = -154.0
# Episode 917: Total Reward = -139.0
# Episode 918: Total Reward = -152.0
# Episode 919: Total Reward = -188.0
# Episode 920: Total Reward = -186.0
# Episode 921: Total Reward = -190.0
# Episode 922: Total Reward = -145.0
# Episode 923: Total Reward = -148.0
# Episode 924: Total Reward = -190.0
# Episode 925: Total Reward = -229.0
# Episode 926: Total Reward = -144.0
# Episode 927: Total Reward = -203.0
# Episode 928: Total Reward = -197.0
# Episode 929: Total Reward = -203.0
# Episode 930: Total Reward = -147.0
# Episode 931: Total Reward = -193.0
# Episode 932: Total Reward = -191.0
# Episode 933: Total Reward = -190.0
# Episode 934: Total Reward = -150.0
# Episode 935: Total Reward = -147.0
# Episode 936: Total Reward = -139.0
# Episode 937: Total Reward = -184.0
# Episode 938: Total Reward = -157.0
# Episode 939: Total Reward = -141.0
# Episode 940: Total Reward = -233.0
# Episode 941: Total Reward = -157.0
# Episode 942: Total Reward = -238.0
# Episode 943: Total Reward = -289.0
# Episode 944: Total Reward = -203.0
# Episode 945: Total Reward = -227.0
# Episode 946: Total Reward = -161.0
# Episode 947: Total Reward = -226.0
# Episode 948: Total Reward = -157.0
# Episode 949: Total Reward = -220.0
# Episode 950: Total Reward = -154.0
# Episode 951: Total Reward = -143.0
# Episode 952: Total Reward = -163.0
# Episode 953: Total Reward = -200.0
# Episode 954: Total Reward = -219.0
# Episode 955: Total Reward = -157.0
# Episode 956: Total Reward = -143.0
# Episode 957: Total Reward = -148.0
# Episode 958: Total Reward = -151.0
# Episode 959: Total Reward = -126.0
# Episode 960: Total Reward = -149.0
# Episode 961: Total Reward = -153.0
# Episode 962: Total Reward = -223.0
# Episode 963: Total Reward = -173.0
# Episode 964: Total Reward = -168.0
# Episode 965: Total Reward = -208.0
# Episode 966: Total Reward = -186.0
# Episode 967: Total Reward = -150.0
# Episode 968: Total Reward = -153.0
# Episode 969: Total Reward = -154.0
# Episode 970: Total Reward = -217.0
# Episode 971: Total Reward = -135.0
# Episode 972: Total Reward = -134.0
# Episode 973: Total Reward = -259.0
# Episode 974: Total Reward = -223.0
# Episode 975: Total Reward = -149.0
# Episode 976: Total Reward = -307.0
# Episode 977: Total Reward = -156.0
# Episode 978: Total Reward = -184.0
# Episode 979: Total Reward = -153.0
# Episode 980: Total Reward = -189.0
# Episode 981: Total Reward = -251.0
# Episode 982: Total Reward = -188.0
# Episode 983: Total Reward = -228.0
# Episode 984: Total Reward = -150.0
# Episode 985: Total Reward = -219.0
# Episode 986: Total Reward = -185.0
# Episode 987: Total Reward = -190.0
# Episode 988: Total Reward = -224.0
# Episode 989: Total Reward = -150.0
# Episode 990: Total Reward = -2000.0
# Episode 991: Total Reward = -1513.0
# Episode 992: Total Reward = -227.0
# Episode 993: Total Reward = -224.0
# Episode 994: Total Reward = -234.0
# Episode 995: Total Reward = -216.0
# Episode 996: Total Reward = -229.0
# Episode 997: Total Reward = -214.0
# Episode 998: Total Reward = -214.0
# Episode 999: Total Reward = -236.0
# Episode 1000: Total Reward = -220.0
#
# Average return over random policy episodes: -354.672

# %%
#make episode vs returns plot
import matplotlib.pyplot as plt

plt.plot(returns)
plt.xlabel('Episode #')
plt.ylabel('Returns')
plt.show()

# %%
#plot value functions (LLM generated)
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

# Define the ranges for position and velocity
position_range = np.linspace(-1.2, 0.6, 100)
velocity_range = np.linspace(-0.07, 0.07, 100)

# Create a meshgrid for plotting the surface
X, Y = np.meshgrid(position_range, velocity_range)

# Iterate through each Q function and plot the 3D surface
for i, q in enumerate(Q):
    # Compute the predicted Q-values for each state (position, velocity)
    Z = np.array([q.predict((x, y)) for x, y in zip(np.ravel(X), np.ravel(Y))]).reshape(X.shape)

    # Create a 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Plot the surface
    ax.plot_surface(X, Y, Z, cmap='viridis')

    # Set labels and title
    ax.set_xlabel('Position')
    ax.set_ylabel('Velocity')
    ax.set_zlabel(f'Q-Value (Action {i})')
    ax.set_title(f'Q-Value Surface for Action {i}')

    plt.show()

# %% [markdown]
# # Discussion
#
# Effect of tile coding parameters (number of tilings, resolution).
#  - The coding parameters have a similar effect as learning rate: Too high of a resolution or number of tilings would result in higher amount of time for the algorithm to converge (similar to too low of a learning rate). Too low of a resolution or number of tilings would result in the model not being able to converge at all since it would be constantly overshooting.

# %%
env.close()
